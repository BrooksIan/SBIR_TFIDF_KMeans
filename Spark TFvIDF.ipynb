# %% [markdown]
# ## Data Science In Apache Spark
# ### TF / IDF -> K-Means Clustering
# ### SBIR
#
# **Language**: Scala
# **Requirements**:
# - [HDP 2.6.X]- Spark 2.x
#
# **Author**: Ian Brooks
# **Follow** [LinkedIn - Ian Brooks PhD] (https://www.linkedin.com/in/ianrbrooksphd/)
# **Source Data** [SBIR Search Site](https://www.sbir.gov/sbirsearch/award/all)
#
# **Addtional Information**: The Small Business Innovation Research (SBIR) program is a highly competitive program that encourages domestic small businesses to engage in Federal Research/Research and Development (R/R&D) that has the potential for commercialization. Through a competitive awards-based program, SBIR enables small businesses to explore their technological potential and provides the incentive to profit from its commercialization. By including qualified small businesses in the nation's R&D arena, high-tech innovation is stimulated and the United States gains entrepreneurial spirit as it meets its specific research and development needs.
#
# **File Upload:** Upload the source data json  files to HDFS in the /tmp directory!
#
#     [SBIR](https://s11759.pcdn.co/wp-content/uploads/2018/04/SBIR_logo.jpg "SBIR")

# %% [markdown]
# ##  Download Data from Github

# %%
# !wget https://raw.githubusercontent.com/BrooksIan/SBIR_TFIDF_KMeans/master/sbir-search-results1.json -O sbir-search-results1.json
# Out:
# --2021-03-12 16:47:49--  https://raw.githubusercontent.com/BrooksIan/SBIR_TFIDF_KMeans/master/sbir-search-results1.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3087237 (2.9M) [text/plain]
# Saving to: ‘sbir-search-results1.json’
#
# sbir-search-results 100%[===================>]   2.94M  --.-KB/s    in 0.02s
#
# 2021-03-12 16:47:49 (142 MB/s) - ‘sbir-search-results1.json’ saved [3087237/3087237]

# %%
# !wget https://raw.githubusercontent.com/BrooksIan/SBIR_TFIDF_KMeans/master/sbir-search-results2.json -O sbir-search-results2.json
# Out:
# --2021-03-12 16:47:54--  https://raw.githubusercontent.com/BrooksIan/SBIR_TFIDF_KMeans/master/sbir-search-results2.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2164639 (2.1M) [text/plain]
# Saving to: ‘sbir-search-results2.json’
#
# sbir-search-results 100%[===================>]   2.06M  --.-KB/s    in 0.01s
#
# 2021-03-12 16:47:54 (185 MB/s) - ‘sbir-search-results2.json’ saved [2164639/2164639]

# %%
# !chmod 777 sbir*.json
# !ls -l sbir*.json
# Out:
# -rwxrwxrwx 1 cdsw cdsw 3087237 Mar 12 16:47 sbir-search-results1.json
# -rwxrwxrwx 1 cdsw cdsw 2164639 Mar 12 16:47 sbir-search-results2.json

# %%
# !hdfs dfs -put sbir-search-results1.json /tmp/sbir-search-results1.json
# !hdfs dfs -put sbir-search-results2.json /tmp/sbir-search-results2.json
# Out:
# put: `/tmp/sbir-search-results1.json': File exists
# put: `/tmp/sbir-search-results2.json': File exists

# %%
# !pwd
# Out:
# /home/cdsw

# %%
# !hdfs dfs -ls /tmp
# Out:
# Found 15 items
# drwxr-xr-x   - cdsw cdsw        280 2021-03-12 17:09 /tmp/blockmgr-5ecf08e2-c12a-4a39-8c25-0a4c10f06f37
# -rw-r--r--   1 cdsw cdsw      28672 2021-03-12 16:24 /tmp/history.sqlite
# drwxr-xr-x   - cdsw cdsw         80 2021-03-12 17:16 /tmp/hsperfdata_cdsw
# drwxr-xr-x   - cdsw cdsw         60 2021-03-12 16:24 /tmp/jupyter
# -rw-------   1 cdsw cdsw        872 2021-03-12 17:12 /tmp/krb5cc_8536
# -rw-r--r--   1 cdsw cdsw      59545 2021-03-12 16:45 /tmp/liblz4-java5266801469916681886.so
# -rw-r--r--   1 cdsw cdsw    3087237 2021-03-12 16:31 /tmp/sbir-search-results1.json
# -rw-r--r--   1 cdsw cdsw    2164639 2021-03-12 16:31 /tmp/sbir-search-results2.json
# drwxr-xr-x   - cdsw cdsw         40 2021-03-12 16:40 /tmp/spark-73f6dd3b-e396-41d2-8bda-319878b98628
# drwx------   - cdsw cdsw         80 2021-03-12 16:40 /tmp/spark-ac864729-321e-4878-9721-fa4959998855
# -rw-r--r--   1 cdsw cdsw          0 2021-03-12 16:40 /tmp/spark-driver.log
# ...

# %% [markdown]
# ## Run PyScript

# %%
# !python3  Pyspark_TF_IDF.py
# Out:
# SLF4J: Class path contains multiple SLF4J bindings.
# SLF4J: Found binding in [jar:file:/etc/spark/jars/slf4j-log4j12-1.7.16.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hadoop/lib/slf4j-log4j12.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: Found binding in [jar:file:/usr/lib/hive_warehouse_connector/hive-warehouse-connector-assembly-1.0.0.7.2.2.0-244.jar!/org/slf4j/impl/StaticLoggerBinder.class]
# SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.
# SLF4J: Actual binding is of type [org.slf4j.impl.Log4jLoggerFactory]
# Setting spark.hadoop.yarn.resourcemanager.principal to ibrooks
# root
#  |-- abstract: string (nullable = true)
#  |-- address1: string (nullable = true)
#  |-- address2: string (nullable = true)
#  |-- agency: string (nullable = true)
# ...

# %%
# !ls
# Out:
#  1LSHResults.json		        output1
#  convertNotebooks.py		        Pyspark_TF_IDF.py
#  convertZeppelinNotebook.py	        sbir-search-results1.json
#  LSHResults.csv			        sbir-search-results2.json
#  LSHResults.json		       'Spark Pipeline NLP (7).json'
# 'MLeap - Spark Pipeline NLP (3).json'  'Spark TFvIDF.ipynb'
#  output				        TF_IDF.json
